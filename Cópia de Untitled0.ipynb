# %%
idade1= 18

# %%
idade2= 20

# %%
idade1 + idade2
# Out:
# 38

# %%
somaIdades = idade1 + idade2

# %%
idade1 - idade2
# Out:
# -2

# %%
idade1 * idade2
# Out:
# 360

# %%
idade1 / idade2
# Out:
# 0.9

# %%
idade1 - 10
# Out:
# 8

# %%
idade1 - 15
# Out:
# 3

# %%
idade1 * 4
# Out:
# 72

# %%
idade1 / 5
# Out:
# 3.6

# %%
2 *(idade1 + idade2)
# Out:
# 76

# %%
2 * idade1 + 3 * idade2 / 4
# Out:
# 51.0

# %%
(2 * idade1 + 3 * idade2) / 4
# Out:
# 24.0

# %%
idade1 ** 2
# Out:
# 324

# %%
15 ** 2
# Out:
# 225

# %%
idade2 // idade1
# Out:
# 1

# %%
idade2 / idade1
# Out:
# 1.1111111111111112

# %%
idade2 % idade1
# Out:
# 2

# %%
sobrenome = " Amorim"

# %%
print(nome + sobrenome)
# Out:
# Laís Amorim

# %%
print(nome + " " + sobrenome)
# Out:
# Laís  Amorim

# %%
print('Olá, ', nome, 'você tem ', idade1 + 15, 'anos.')
# Out:
# Olá,  Laís você tem  33 anos.

# %%
print('olá,' , nome, '\n' , 'você tem ' ,idade1 + 15 , 'anos.')
# Out:
# olá, Laís
#  você tem  33 anos.

# %%
input('Digite o seu nome: ')
# Out:
# Digite o seu nome: Laís
# 'Laís'

# %%
nome = input('Digite o seu nome: ')
# Out:
# Digite o seu nome: Laís

# %%
nome = str(input('Digite o seu nome: '))
# Out:
# Digite o seu nome: Laís
